# %%
import numpy as np
import plotly.graph_objects as go

# %% [markdown]
# # Функции

# %%
def sigmoid(x):
    return 1/ (1 + np.exp(-x))

def savePoints(points, filename):
    with open(filename, 'w') as f:
        for point in points:
            f.write(f"{point[0]} {point[1]} {point[2]}\n")

def loadPoints(filename):
    points = []
    with open(filename, 'r') as f:
        for line in f:
            x, y, z = map(float, line.split())
            points.append((x, y, z))
    return points

def Relu(x):
    return np.maximum(0, x)

# %% [markdown]
# # Генерация точек

# %%
def generate_points(n):
    points = []
    for i in range(n):
        x = np.random.uniform(-1, 1)
        y = np.random.uniform(-1, 1)
        z = np.random.uniform(-1, 1)
        points.append((x, y, z))
    return points

# %% [markdown]
# # Генерация точек

# %%
# savePoints(generate_points(1000), 'points_training.txt')

# %% [markdown]
# # Визуализация точек

# %%
def interactive_3d_plot(points):
    octant_data = [[] for _ in range(8)]
    
    for x, y, z in points:
        octant = 0
        if x < 0: octant += 1
        if y < 0: octant += 2  
        if z < 0: octant += 4
        octant_data[octant].append((x, y, z))
    
    fig = go.Figure()

    fig.add_trace(go.Scatter3d(x=[-1, 1], y=[0, 0], z=[0, 0], 
                              mode='lines', line=dict(color='black', width=5), 
                              name='Ось X'))
    fig.add_trace(go.Scatter3d(x=[0, 0], y=[-1, 1], z=[0, 0], 
                              mode='lines', line=dict(color='black', width=5), 
                              name='Ось Y'))
    fig.add_trace(go.Scatter3d(x=[0, 0], y=[0, 0], z=[-1, 1], 
                              mode='lines', line=dict(color='black', width=5), 
                              name='Ось Z'))
    
    colors = ['red', 'blue', 'green', 'orange', 'purple', 'brown', 'pink', 'gray']
    names = ['(+,+,+)', '(-,+,+)', '(+,-,+)', '(-,-,+)', 
             '(+,+,-)', '(-,+,-)', '(+,-,-)', '(-,-,-)']
    
    for i, (data, color, name) in enumerate(zip(octant_data, colors, names)):
        if data:
            x_coords, y_coords, z_coords = zip(*data)
            fig.add_trace(go.Scatter3d(
                x=x_coords, y=y_coords, z=z_coords,
                mode='markers',
                marker=dict(size=8, color=color),
                name=f'Октант {i+1} {name}'
            ))
    
    fig.update_layout(
        width=800, height=800,
        title='Интерактивная 3D визуализация',
        scene=dict(xaxis_title='X', yaxis_title='Y', zaxis_title='Z')
    )
    
    fig.show()

# %%
interactive_3d_plot(loadPoints('points_training.txt'))

# %%
interactive_3d_plot(loadPoints('points_inference.txt'))

# %% [markdown]
# # Открытие файлов с точками и присвоение классов

# %%
def getOctant(x,y,z):
    octant = 0
    if x < 0: octant += 1
    if y < 0: octant += 2
    if z < 0: octant += 4
    return octant + 1

def loadPointsWithClasses(filename):
    points = []
    octants = []
    with open(filename, 'r') as f:
        for line in f:
            x, y, z = map(float, line.split())
            points.append((x, y, z))
            octants.append(getOctant(x, y, z))
    return np.array(points), np.array(octants) 

def makeTargetVector(octants):
    targets = np.zeros((len(octants), 8))
    for i, octant in enumerate(octants):
        targets[i][octant-1] = 1
    return targets

xTrain, yClasses = loadPointsWithClasses('points_training.txt')
yTrain = makeTargetVector(yClasses) 

print(f"Точка: {xTrain[0]}")
print(f"Октант: {yClasses[0]}")  
print(f"Целевой вектор: {yTrain[0]}")
# Out:
# Точка: [ 0.89286915 -0.22905191 -0.11924598]
# Октант: 7
# Целевой вектор: [0. 0. 0. 0. 0. 0. 1. 0.]

# %% [markdown]
# # Перцептрон

# %%
class Perceptron:
    def __init__(self, input_size):
        self.weights = np.random.rand(8, input_size)
        self.bias = np.random.rand(8)

    def forward(self, x):
        return sigmoid(np.dot(self.weights, x) + self.bias)

    def train(self, x, y, y_true, learning_rate=0.01, target_accuracy=0.95, weight_decay=0.001, max_epochs=400):
        epoch = 0
        while epoch < max_epochs:
            for i in range(len(x)):
                y_pred = self.forward(x[i])
                for j in range(8):
                    error = y[i][j] - y_pred[j]
                    self.weights[j] = self.weights[j] + learning_rate * error * np.array(x[i]) * (1-weight_decay)
                    self.bias[j] += learning_rate * error
            
            if epoch % 10 == 0:
                correct = 0
                for i in range(len(x)):
                    prediction = np.argmax(self.forward(x[i])) + 1
                    if prediction == y_true[i]:
                        correct += 1
                accuracy = correct / len(x)
                print(f"Эпоха {epoch}, точность: {accuracy:.2%}")
                
                if accuracy >= target_accuracy:
                    print(f"Достигнута целевая точность {target_accuracy:.0%}")
                    break
            
            epoch += 1


    def saveWeights(self, filename):
        np.savetxt(filename + '.txt', self.weights)
        np.savetxt(filename + '_bias.txt', self.bias)

    def loadWeights(self, filename):
        self.weights = np.loadtxt(filename + '.txt')
        self.bias = np.loadtxt(filename + '_bias.txt')
    
    def printResults(self, x, y):
        correct = 0
        for i in range(len(x)):
            output = self.forward(x[i])
            prediction = np.argmax(output) + 1
            print(f"Точка: {x[i]}")
            print(f"Реальный октант: {y[i]}")
            print(f"Предсказание: {prediction}")
            if prediction == y[i]:
                correct += 1
            print()
        
        print(f"Точность: {correct}/{len(y)} = {correct/len(y):.2%}")

    def getAnswerForOnePoint(self, x, y, z):
        point = np.array([x, y, z])
        output = self.forward(point)
        print(f"Ответ: {np.argmax(output) + 1}")

# %% [markdown]
# # Реализация

# %%
xInference, yInference = loadPointsWithClasses('points_inference.txt')

perceptron = Perceptron(3)
perceptron.train(xTrain, yTrain, yClasses)
perceptron.saveWeights('weights')
perceptron.printResults(xInference, yInference)
# Out:
# Эпоха 0, точность: 71.50%
# Эпоха 10, точность: 94.10%
# Эпоха 20, точность: 94.90%
# Эпоха 30, точность: 95.30%
# Достигнута целевая точность 95%
# Точка: [0.77713774 0.1630673  0.02121406]
# Реальный октант: 1
# Предсказание: 1
#
# Точка: [0.89820353 0.85970497 0.67630812]
# Реальный октант: 1
# Предсказание: 1
#
# Точка: [ 0.95817417  0.07873563 -0.05771293]
# Реальный октант: 5
# Предсказание: 5
#
# Точка: [0.33069516 0.20559343 0.59636621]
# Реальный октант: 1
# Предсказание: 1
#
# Точка: [-0.32548394  0.81423516 -0.76531842]
# Реальный октант: 6
# Предсказание: 6
#
# Точка: [0.37742891 0.57619167 0.82238806]
# Реальный октант: 1
# Предсказание: 1
#
# Точка: [-0.72216871  0.55858439 -0.12417909]
# Реальный октант: 6
# Предсказание: 6
#
# Точка: [-0.24043499  0.2679133   0.22339181]
# Реальный октант: 2
# Предсказание: 2
#
# Точка: [ 0.20655855  0.34916856 -0.66664467]
# Реальный октант: 5
# Предсказание: 5
#
# Точка: [-0.93097335  0.6592487   0.2650316 ]
# Реальный октант: 2
# Предсказание: 2
#
# Точка: [ 0.70428692  0.04287356 -0.22516154]
# Реальный октант: 5
# Предсказание: 5
#
# Точка: [-0.53381453 -0.12315559 -0.2791053 ]
# Реальный октант: 8
# Предсказание: 8
#
# Точка: [-0.67971643  0.64107104  0.97959453]
# Реальный октант: 2
# Предсказание: 2
#
# Точка: [ 0.24287195 -0.27880682 -0.35438819]
# Реальный октант: 7
# Предсказание: 7
#
# Точка: [ 0.56060787 -0.1283278   0.74380874]
# Реальный октант: 3
# Предсказание: 3
#
# Точка: [ 0.42777137 -0.34271725  0.42887488]
# Реальный октант: 3
# Предсказание: 3
#
# Точка: [-0.77252625  0.23389269  0.1353092 ]
# Реальный октант: 2
# Предсказание: 2
#
# Точка: [-0.45026382 -0.06379818  0.5247239 ]
# Реальный октант: 4
# Предсказание: 4
#
# Точка: [ 0.54163836 -0.55788019  0.49296226]
# Реальный октант: 3
# Предсказание: 3
#
# Точка: [-0.10068221  0.78049678 -0.56519685]
# Реальный октант: 6
# Предсказание: 5
#
# Точка: [ 0.98273297 -0.00401119  0.71282762]
# Реальный октант: 3
# Предсказание: 1
#
# Точка: [ 0.36738419 -0.52465719  0.52575453]
# Реальный октант: 3
# Предсказание: 3
#
# Точка: [-0.51182031 -0.86490226  0.09442529]
# Реальный октант: 4
# Предсказание: 4
#
# Точка: [ 0.27212785  0.01512276 -0.68667997]
# Реальный октант: 5
# Предсказание: 5
#
# Точка: [-0.43651583  0.22586932  0.90146559]
# Реальный октант: 2
# Предсказание: 2
#
# Точка: [-0.89742134  0.21136686 -0.79539244]
# Реальный октант: 6
# Предсказание: 6
#
# Точка: [-0.8021929  -0.66310845 -0.9176101 ]
# Реальный октант: 8
# Предсказание: 8
#
# Точка: [-0.95710111  0.69950464  0.34803226]
# Реальный октант: 2
# Предсказание: 2
#
# Точка: [ 0.03830182  0.19124725 -0.04199634]
# Реальный октант: 5
# Предсказание: 5
#
# Точка: [-0.18008479 -0.77766947  0.52135365]
# Реальный октант: 4
# Предсказание: 4
#
# Точка: [ 0.53823108 -0.70824452  0.62963057]
# Реальный октант: 3
# Предсказание: 3
#
# Точка: [-0.53560398 -0.49411915  0.45406661]
# Реальный октант: 4
# Предсказание: 4
#
# Точка: [-0.63423828  0.75179284 -0.02272436]
# Реальный октант: 6
# Предсказание: 2
#
# Точка: [ 0.86736749 -0.53698304 -0.8045459 ]
# Реальный октант: 7
# Предсказание: 7
#
# Точка: [ 0.23796781  0.90475994 -0.49917995]
# Реальный октант: 5
# Предсказание: 5
#
# Точка: [-0.35870776  0.95035802  0.81845821]
# Реальный октант: 2
# Предсказание: 2
#
# Точка: [-0.8235435   0.38301724 -0.4273949 ]
# Реальный октант: 6
# Предсказание: 6
#
# Точка: [-0.18169727  0.79304766  0.44736866]
# Реальный октант: 2
# Предсказание: 2
#
# Точка: [-0.00079596 -0.66947151 -0.47210214]
# Реальный октант: 8
# Предсказание: 7
#
# Точка: [-0.47192563  0.86504032 -0.08567465]
# Реальный октант: 6
# Предсказание: 2
#
# Точка: [-0.04424493 -0.24494355 -0.5203338 ]
# Реальный октант: 8
# Предсказание: 8
#
# Точка: [-0.52054484 -0.58673437 -0.15330225]
# Реальный октант: 8
# Предсказание: 8
#
# Точка: [ 0.95836742  0.06136578 -0.93468442]
# Реальный октант: 5
# Предсказание: 5
#
# Точка: [ 0.40670947 -0.3784395   0.49340372]
# Реальный октант: 3
# Предсказание: 3
#
# Точка: [ 0.65102577 -0.6907074  -0.20029927]
# Реальный октант: 7
# Предсказание: 7
#
# Точка: [ 0.08411788 -0.74784238  0.90609721]
# Реальный октант: 3
# Предсказание: 3
#
# Точка: [ 0.07769839 -0.63161021 -0.26632873]
# Реальный октант: 7
# Предсказание: 7
#
# Точка: [ 0.51507988  0.24758989 -0.18877056]
# Реальный октант: 5
# Предсказание: 5
#
# Точка: [ 0.41114423 -0.54617207 -0.47711121]
# Реальный октант: 7
# Предсказание: 7
#
# Точка: [ 0.30860794 -0.50639293 -0.78835266]
# Реальный октант: 7
# Предсказание: 7
#
# Точка: [ 0.09418483 -0.51914388 -0.91485124]
# Реальный октант: 7
# Предсказание: 7
#
# Точка: [-0.5977592  -0.12239167 -0.85368646]
# Реальный октант: 8
# Предсказание: 8
#
# Точка: [-0.79093576 -0.013625    0.36942092]
# Реальный октант: 4
# Предсказание: 4
#
# Точка: [ 0.81003034 -0.42233279  0.85190824]
# Реальный октант: 3
# Предсказание: 3
#
# Точка: [0.36055301 0.7637653  0.64667327]
# Реальный октант: 1
# Предсказание: 1
#
# Точка: [ 0.71715774 -0.40065099  0.38061912]
# Реальный октант: 3
# Предсказание: 3
#
# Точка: [-0.43465472 -0.68565337 -0.87922236]
# Реальный октант: 8
# Предсказание: 8
#
# Точка: [ 0.48685736  0.33665723 -0.73644097]
# Реальный октант: 5
# Предсказание: 5
#
# Точка: [-0.47329598 -0.90600457 -0.65072717]
# Реальный октант: 8
# Предсказание: 8
#
# Точка: [0.42427339 0.90168426 0.64546363]
# Реальный октант: 1
# Предсказание: 1
#
# Точка: [-0.38734762 -0.07023173 -0.5116205 ]
# Реальный октант: 8
# Предсказание: 8
#
# Точка: [ 0.40173956  0.45316525 -0.01837799]
# Реальный октант: 5
# Предсказание: 5
#
# Точка: [-0.2620777  -0.20924616 -0.30247175]
# Реальный октант: 8
# Предсказание: 8
#
# Точка: [ 0.17919037 -0.63421879  0.33492086]
# Реальный октант: 3
# Предсказание: 3
#
# Точка: [ 0.17735056 -0.24803337 -0.01285293]
# Реальный октант: 7
# Предсказание: 7
#
# Точка: [ 0.68684876  0.55237266 -0.28718818]
# Реальный октант: 5
# Предсказание: 5
#
# Точка: [0.03898235 0.88049645 0.02637257]
# Реальный октант: 1
# Предсказание: 2
#
# Точка: [-0.23631384 -0.00564306  0.25415942]
# Реальный октант: 4
# Предсказание: 4
#
# Точка: [ 0.11704844  0.34831498 -0.63975348]
# Реальный октант: 5
# Предсказание: 5
#
# Точка: [0.2929824  0.86255934 0.36227589]
# Реальный октант: 1
# Предсказание: 1
#
# Точка: [-0.09256355 -0.91151941 -0.62408598]
# Реальный октант: 8
# Предсказание: 8
#
# Точка: [-0.95761208 -0.7416254  -0.68633141]
# Реальный октант: 8
# Предсказание: 8
#
# Точка: [ 0.60979944 -0.84215824 -0.74036198]
# Реальный октант: 7
# Предсказание: 7
#
# Точка: [ 0.54709442 -0.919245    0.88656116]
# Реальный октант: 3
# Предсказание: 3
#
# Точка: [-0.67477234 -0.29332665 -0.69699312]
# Реальный октант: 8
# Предсказание: 8
#
# Точка: [-0.86565785 -0.83574152 -0.30999134]
# Реальный октант: 8
# Предсказание: 8
#
# Точка: [-0.96346237  0.01670965 -0.27652828]
# Реальный октант: 6
# Предсказание: 8
#
# Точка: [-0.72684504 -0.0200247   0.91462703]
# Реальный октант: 4
# Предсказание: 4
#
# Точка: [ 0.38107826  0.43001214 -0.8770752 ]
# Реальный октант: 5
# Предсказание: 5
#
# Точка: [-0.49009535  0.91138305 -0.07917368]
# Реальный октант: 6
# Предсказание: 2
#
# Точка: [-0.21858146  0.45634192  0.56600546]
# Реальный октант: 2
# Предсказание: 2
#
# Точка: [-0.6029125  -0.74817475  0.36584444]
# Реальный октант: 4
# Предсказание: 4
#
# Точка: [ 0.99576794 -0.90339135  0.11701396]
# Реальный октант: 3
# Предсказание: 3
#
# Точка: [ 0.22194143  0.20089395 -0.2650427 ]
# Реальный октант: 5
# Предсказание: 5
#
# Точка: [-0.29048551 -0.50910066  0.46340205]
# Реальный октант: 4
# Предсказание: 4
#
# Точка: [ 0.42262169 -0.26385772 -0.98713777]
# Реальный октант: 7
# Предсказание: 7
#
# Точка: [ 0.14603732  0.47739284 -0.85393765]
# Реальный октант: 5
# Предсказание: 5
#
# Точка: [ 0.37935133 -0.03270487  0.67025177]
# Реальный октант: 3
# Предсказание: 3
#
# Точка: [ 0.4646403  -0.06655037  0.15002628]
# Реальный октант: 3
# Предсказание: 3
#
# Точка: [-0.01604434  0.05902612  0.17679265]
# Реальный октант: 2
# Предсказание: 2
#
# Точка: [-0.35218711 -0.48687946 -0.36861351]
# Реальный октант: 8
# Предсказание: 8
#
# Точка: [ 0.51678492 -0.48385139 -0.98782223]
# Реальный октант: 7
# Предсказание: 7
#
# Точка: [ 0.61722132  0.68211769 -0.55246076]
# Реальный октант: 5
# Предсказание: 5
#
# Точка: [-0.65756204  0.71816418  0.502582  ]
# Реальный октант: 2
# Предсказание: 2
#
# Точка: [ 0.75916332  0.47733303 -0.55096425]
# Реальный октант: 5
# Предсказание: 5
#
# Точка: [-7.60698024e-01 -5.34092709e-01  6.83754757e-04]
# Реальный октант: 4
# Предсказание: 4
#
# Точка: [ 0.17998006  0.75307281 -0.33553841]
# Реальный октант: 5
# Предсказание: 5
#
# Точка: [-0.89426555  0.89639354 -0.72623379]
# Реальный октант: 6
# Предсказание: 6
#
# Точка: [0.03122081 0.6635028  0.34331465]
# Реальный октант: 1
# Предсказание: 2
#
# Точка: [-0.6571665  -0.62270047 -0.37843243]
# Реальный октант: 8
# Предсказание: 8
#
# Точность: 91/100 = 91.00%

# %%
perceptron2 = Perceptron(3)
perceptron2.loadWeights('weights')
perceptron2.getAnswerForOnePoint(-0.11, 0.3, -1)
# Out:
# Ответ: 5
